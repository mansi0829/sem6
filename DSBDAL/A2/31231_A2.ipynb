# %%
import pandas as pd

# %%
df1 = pd.read_csv("/home/pict/Downloads/sem6-main/DSBDAL/A2/StudentData.csv")

# %%
df2 = pd.read_csv("/home/pict/Downloads/sem6-main/DSBDAL/A2/AcademicPerformance.csv")

# %%
display(df1)
# Out:
#     S No.  Roll No              Name
# 0       1    31001      Kellie Arias
# 1       2    31002    Mickey Schultz
# 2       3    31003        Loyd Rubio
# 3       4    31004       Josef Burns
# 4       5    31005       Lisa Torres
# 5       6    31006   Reuben Davidson
# 6       7    31007      Brooks Hicks
# 7       8    31008     Leslie Pierce
# 8       9    31009      Deirdre Chen
# 9      10    31010      Daron Lawson
# 10     11    31011     Josefa Monroe
# 11     12    31012     Abraham Green
# 12     13    31013    Refugio Zuniga
# 13     14    31014     Jerrell Cline
# 14     15    31015          Dan Mora
# 15     16    31016    Maritza Miller
# 16     17    31017       Chase Owens
# 17     18    31018     Jonathan Sims
# 18     19    31019    Donovan Morrow
# 19     20    31020        Leta Olsen
# 20     21    31021   Randall Winters
# 21     22    31022         Jerold Li
# 22     23    31023      Hans Fleming
# 23     24    31024     Denise Juarez
# ...

# %%
display(df2)
# Out:
#     S No.  Roll No.  DBMS  CNS  DS  TOC  SPOS
# 0       1     31001    45   23  45   50    38
# 1       2     31002    33   34  33   40    39
# 2       3     31003    50   34  50   38    40
# 3       4     31004    40   42  40   36    35
# 4       5     31005    38   14  38   42    30
# 5       6     31006    36   13  36   34    46
# 6       7     31007    42   42  42   50    50
# 7       8     31008    34   23  34   45    38
# 8       9     31009    34   34  34   33    36
# 9      10     31010    43   38  43   50    42
# 10     11     31011    22   39  22   40    34
# 11     12     31012    41   40  41   38    23
# 12     13     31013    43   35  43   36    34
# 13     14     31014    23   30  23   42    34
# 14     15     31015    23   46  23   34    42
# 15     16     31016    34   50  34   45    14
# 16     17     31017    34   38  34   33    13
# 17     18     31018    42   36  42   50    42
# 18     19     31019    14   42  14   40    23
# ...

# %%
pd.concat([df1, df2], axis=1)
# Out:
#     S No.  Roll No              Name  S No.  Roll No.  DBMS  CNS  DS  TOC  \
# 0       1    31001      Kellie Arias      1     31001    45   23  45   50
# 1       2    31002    Mickey Schultz      2     31002    33   34  33   40
# 2       3    31003        Loyd Rubio      3     31003    50   34  50   38
# 3       4    31004       Josef Burns      4     31004    40   42  40   36
# 4       5    31005       Lisa Torres      5     31005    38   14  38   42
# 5       6    31006   Reuben Davidson      6     31006    36   13  36   34
# 6       7    31007      Brooks Hicks      7     31007    42   42  42   50
# 7       8    31008     Leslie Pierce      8     31008    34   23  34   45
# 8       9    31009      Deirdre Chen      9     31009    34   34  34   33
# 9      10    31010      Daron Lawson     10     31010    43   38  43   50
# 10     11    31011     Josefa Monroe     11     31011    22   39  22   40
# 11     12    31012     Abraham Green     12     31012    41   40  41   38
# ...

# %%
pd.concat([df1, df2], axis=1).T.drop_duplicates().T
# Out:
#    S No. Roll No              Name DBMS CNS TOC SPOS
# 0      1   31001      Kellie Arias   45  23  50   38
# 1      2   31002    Mickey Schultz   33  34  40   39
# 2      3   31003        Loyd Rubio   50  34  38   40
# 3      4   31004       Josef Burns   40  42  36   35
# 4      5   31005       Lisa Torres   38  14  42   30
# 5      6   31006   Reuben Davidson   36  13  34   46
# 6      7   31007      Brooks Hicks   42  42  50   50
# 7      8   31008     Leslie Pierce   34  23  45   38
# 8      9   31009      Deirdre Chen   34  34  33   36
# 9     10   31010      Daron Lawson   43  38  50   42
# 10    11   31011     Josefa Monroe   22  39  40   34
# 11    12   31012     Abraham Green   41  40  38   23
# 12    13   31013    Refugio Zuniga   43  35  36   34
# 13    14   31014     Jerrell Cline   23  30  42   34
# 14    15   31015          Dan Mora   23  46  34   42
# 15    16   31016    Maritza Miller   34  50  45   14
# 16    17   31017       Chase Owens   34  38  33   13
# ...

# %%
display(pd.merge(df1, df2))
# Out:
#     S No.  Roll No              Name  Roll No.  DBMS  CNS  DS  TOC  SPOS
# 0       1    31001      Kellie Arias     31001    45   23  45   50    38
# 1       2    31002    Mickey Schultz     31002    33   34  33   40    39
# 2       3    31003        Loyd Rubio     31003    50   34  50   38    40
# 3       4    31004       Josef Burns     31004    40   42  40   36    35
# 4       5    31005       Lisa Torres     31005    38   14  38   42    30
# 5       6    31006   Reuben Davidson     31006    36   13  36   34    46
# 6       7    31007      Brooks Hicks     31007    42   42  42   50    50
# 7       8    31008     Leslie Pierce     31008    34   23  34   45    38
# 8       9    31009      Deirdre Chen     31009    34   34  34   33    36
# 9      10    31010      Daron Lawson     31010    43   38  43   50    42
# 10     11    31011     Josefa Monroe     31011    22   39  22   40    34
# 11     12    31012     Abraham Green     31012    41   40  41   38    23
# ...

# %%
display(pd.merge(df1, df2).T.drop_duplicates().T)
# Out:
#    S No. Roll No              Name DBMS CNS TOC SPOS
# 0      1   31001      Kellie Arias   45  23  50   38
# 1      2   31002    Mickey Schultz   33  34  40   39
# 2      3   31003        Loyd Rubio   50  34  38   40
# 3      4   31004       Josef Burns   40  42  36   35
# 4      5   31005       Lisa Torres   38  14  42   30
# 5      6   31006   Reuben Davidson   36  13  34   46
# 6      7   31007      Brooks Hicks   42  42  50   50
# 7      8   31008     Leslie Pierce   34  23  45   38
# 8      9   31009      Deirdre Chen   34  34  33   36
# 9     10   31010      Daron Lawson   43  38  50   42
# 10    11   31011     Josefa Monroe   22  39  40   34
# 11    12   31012     Abraham Green   41  40  38   23
# 12    13   31013    Refugio Zuniga   43  35  36   34
# 13    14   31014     Jerrell Cline   23  30  42   34
# 14    15   31015          Dan Mora   23  46  34   42
# 15    16   31016    Maritza Miller   34  50  45   14
# 16    17   31017       Chase Owens   34  38  33   13
# ...

# %%
display(pd.merge(df1, df2, how="left",indicator = True))
# Out:
#     S No.  Roll No              Name  Roll No.  DBMS  CNS  DS  TOC  SPOS  \
# 0       1    31001      Kellie Arias     31001    45   23  45   50    38
# 1       2    31002    Mickey Schultz     31002    33   34  33   40    39
# 2       3    31003        Loyd Rubio     31003    50   34  50   38    40
# 3       4    31004       Josef Burns     31004    40   42  40   36    35
# 4       5    31005       Lisa Torres     31005    38   14  38   42    30
# 5       6    31006   Reuben Davidson     31006    36   13  36   34    46
# 6       7    31007      Brooks Hicks     31007    42   42  42   50    50
# 7       8    31008     Leslie Pierce     31008    34   23  34   45    38
# 8       9    31009      Deirdre Chen     31009    34   34  34   33    36
# 9      10    31010      Daron Lawson     31010    43   38  43   50    42
# 10     11    31011     Josefa Monroe     31011    22   39  22   40    34
# 11     12    31012     Abraham Green     31012    41   40  41   38    23
# ...

# %%
display(pd.merge(df1, df2, how="right",indicator = True))
# Out:
#     S No.  Roll No              Name  Roll No.  DBMS  CNS  DS  TOC  SPOS  \
# 0       1    31001      Kellie Arias     31001    45   23  45   50    38
# 1       2    31002    Mickey Schultz     31002    33   34  33   40    39
# 2       3    31003        Loyd Rubio     31003    50   34  50   38    40
# 3       4    31004       Josef Burns     31004    40   42  40   36    35
# 4       5    31005       Lisa Torres     31005    38   14  38   42    30
# 5       6    31006   Reuben Davidson     31006    36   13  36   34    46
# 6       7    31007      Brooks Hicks     31007    42   42  42   50    50
# 7       8    31008     Leslie Pierce     31008    34   23  34   45    38
# 8       9    31009      Deirdre Chen     31009    34   34  34   33    36
# 9      10    31010      Daron Lawson     31010    43   38  43   50    42
# 10     11    31011     Josefa Monroe     31011    22   39  22   40    34
# 11     12    31012     Abraham Green     31012    41   40  41   38    23
# ...

# %%
display(pd.merge(df1, df2, how="left",indicator = True, validate = 'one_to_many'))
# Out:
#     S No.  Roll No              Name  Roll No.  DBMS  CNS  DS  TOC  SPOS  \
# 0       1    31001      Kellie Arias     31001    45   23  45   50    38
# 1       2    31002    Mickey Schultz     31002    33   34  33   40    39
# 2       3    31003        Loyd Rubio     31003    50   34  50   38    40
# 3       4    31004       Josef Burns     31004    40   42  40   36    35
# 4       5    31005       Lisa Torres     31005    38   14  38   42    30
# 5       6    31006   Reuben Davidson     31006    36   13  36   34    46
# 6       7    31007      Brooks Hicks     31007    42   42  42   50    50
# 7       8    31008     Leslie Pierce     31008    34   23  34   45    38
# 8       9    31009      Deirdre Chen     31009    34   34  34   33    36
# 9      10    31010      Daron Lawson     31010    43   38  43   50    42
# 10     11    31011     Josefa Monroe     31011    22   39  22   40    34
# 11     12    31012     Abraham Green     31012    41   40  41   38    23
# ...

# %%
display(pd.merge(df1, df2, how="inner",indicator = True, validate = 'one_to_many'))
# Out:
#     S No.  Roll No              Name  Roll No.  DBMS  CNS  DS  TOC  SPOS  \
# 0       1    31001      Kellie Arias     31001    45   23  45   50    38
# 1       2    31002    Mickey Schultz     31002    33   34  33   40    39
# 2       3    31003        Loyd Rubio     31003    50   34  50   38    40
# 3       4    31004       Josef Burns     31004    40   42  40   36    35
# 4       5    31005       Lisa Torres     31005    38   14  38   42    30
# 5       6    31006   Reuben Davidson     31006    36   13  36   34    46
# 6       7    31007      Brooks Hicks     31007    42   42  42   50    50
# 7       8    31008     Leslie Pierce     31008    34   23  34   45    38
# 8       9    31009      Deirdre Chen     31009    34   34  34   33    36
# 9      10    31010      Daron Lawson     31010    43   38  43   50    42
# 10     11    31011     Josefa Monroe     31011    22   39  22   40    34
# 11     12    31012     Abraham Green     31012    41   40  41   38    23
# ...

# %%
display(pd.merge(df1, df2, how="outer",indicator = True, validate = 'one_to_many'))
# Out:
#     S No.  Roll No              Name  Roll No.  DBMS  CNS  DS  TOC  SPOS  \
# 0       1    31001      Kellie Arias     31001    45   23  45   50    38
# 1       2    31002    Mickey Schultz     31002    33   34  33   40    39
# 2       3    31003        Loyd Rubio     31003    50   34  50   38    40
# 3       4    31004       Josef Burns     31004    40   42  40   36    35
# 4       5    31005       Lisa Torres     31005    38   14  38   42    30
# 5       6    31006   Reuben Davidson     31006    36   13  36   34    46
# 6       7    31007      Brooks Hicks     31007    42   42  42   50    50
# 7       8    31008     Leslie Pierce     31008    34   23  34   45    38
# 8       9    31009      Deirdre Chen     31009    34   34  34   33    36
# 9      10    31010      Daron Lawson     31010    43   38  43   50    42
# 10     11    31011     Josefa Monroe     31011    22   39  22   40    34
# 11     12    31012     Abraham Green     31012    41   40  41   38    23
# ...

# %%
 df1.join(df2, rsuffix=" ", lsuffix=" ")
# Out:
#     S No.   Roll No              Name  S No.   Roll No.  DBMS  CNS  DS  TOC  \
# 0        1    31001      Kellie Arias       1     31001    45   23  45   50
# 1        2    31002    Mickey Schultz       2     31002    33   34  33   40
# 2        3    31003        Loyd Rubio       3     31003    50   34  50   38
# 3        4    31004       Josef Burns       4     31004    40   42  40   36
# 4        5    31005       Lisa Torres       5     31005    38   14  38   42
# 5        6    31006   Reuben Davidson       6     31006    36   13  36   34
# 6        7    31007      Brooks Hicks       7     31007    42   42  42   50
# 7        8    31008     Leslie Pierce       8     31008    34   23  34   45
# 8        9    31009      Deirdre Chen       9     31009    34   34  34   33
# 9       10    31010      Daron Lawson      10     31010    43   38  43   50
# 10      11    31011     Josefa Monroe      11     31011    22   39  22   40
# ...

# %%
dfmerge = pd.merge(df1, df2).T.drop_duplicates().T

# %%
dfmerge.sum()
# Out:
# S No.                                                    465
# Roll No                                               930465
#  Name      Kellie AriasMickey SchultzLoyd RubioJosef Burn...
# DBMS                                                    1061
# CNS                                                     1026
# TOC                                                     1176
# SPOS                                                    1071
# dtype: object

# %%
dfmerge['total'] = dfmerge['DBMS']+ dfmerge['CNS'] + dfmerge['DS'] + dfmerge['TOC'] + dfmerge['SPOS']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DS'
#
# The above exception was the direct cause of the following exception:
#
# ...
